# %%
import pandas as pd

# %%
data_path = 'data/tweets/'

df = pd.read_csv(data_path+'data_teste.csv')

# %%
df.sample(10)
# Out:
#                          created_at             tweet_id  \
# 300  Mon Sep 26 02:54:48 +0000 2022  1574230982181404672
# 342  Mon Sep 26 02:47:20 +0000 2022  1574229103984738304
# 444  Mon Sep 26 02:06:55 +0000 2022  1574218932470403073
# 394  Mon Sep 26 02:33:45 +0000 2022  1574225682271555584
# 442  Mon Sep 26 02:07:04 +0000 2022  1574218970927865856
# 151  Mon Sep 26 03:19:30 +0000 2022  1574237199327010816
# 523  Sun Sep 25 13:55:48 +0000 2022  1574034941327052800
# 177  Mon Sep 26 03:14:06 +0000 2022  1574235836832534534
# 232  Mon Sep 26 03:05:07 +0000 2022  1574233576748498944
# 522  Sun Sep 25 14:00:19 +0000 2022  1574036075877699584
#
#                                          tweet_content  \
# 300  Fiquei com a impressão que estão correndo muit...
# 342  O pai do ano🗣🗣🗣\n#HouseOftheDragon \n#housestr...
# 444  TIVE UMA SENSAÇÃO DE QUE IA DAR MUITA MERDA NE...
# 394  eu o ep inteiro: 🤬😡😤\n\n*dragão aparece*\n\neu...
# 442  Que sejam fortes como a mamãe...\n\n#ACasaDoDr...
# ...

# %%
df[:3]
# Out:
#                        created_at             tweet_id  \
# 0  Mon Sep 26 12:07:14 +0000 2022  1574370007047458816
# 1  Mon Sep 26 12:00:24 +0000 2022  1574368286200008704
# 2  Mon Sep 26 11:59:48 +0000 2022  1574368136907919363
#
#                                        tweet_content  \
# 0  Mano eu to obcecada pelo casal de #HouseOfTheD...
# 1                  SENTADA PARA #HouseOfTheDragonEp6
# 2  Criston Cole mata o Joffrey e tá lá na guarda ...
#
#                                            user_info media urls  \
# 0  {'screen_name': 'monifieldss', 'name': 'Moni',...   NaN  NaN
# 1  {'screen_name': 'Paulaaab24', 'name': 'paulaaa...   NaN  NaN
# 2  {'screen_name': 'BlueVG18', 'name': 'blue', 'i...   NaN  NaN
#
#    user_mentions reply_to quoted_from retweeted_from  \
# 0              0      NaN         NaN            NaN
# 1              0      NaN         NaN            NaN
# 2              0      NaN         NaN            NaN
#
# ...

# %%
import numpy as np

pd.isnull(df.iloc[0]['reply_to'])
# Out:
# True

# %%
df.memory_usage(index=False)
# Out:
# created_at        4400
# tweet_id          4400
# tweet_content     4400
# user_info         4400
# media             4400
# urls              4400
# user_mentions     4400
# reply_to          4400
# quoted_from       4400
# retweeted_from    4400
# hashtags          4400
# dtype: int64

# %%
eval(df.iloc[0]['user_info'])
# Out:
# {'screen_name': 'monifieldss',
#  'name': 'Moni',
#  'id': 1424571368,
#  'description': '',
#  'created_at': 'Mon May 13 03:49:54 +0000 2013'}
